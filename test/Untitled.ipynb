# %%
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr
# %matplotlib notebook

# %%
ds = xr.open_dataset('../fortran/output_water.nc')
other = np.genfromtxt('../fortran/hi.out')

# %%
plt.figure()
ds.q.plot(y='pedge')
plt.gca().invert_yaxis()
plt.gca().set_yscale('log')
plt.xlim(right=0.11)

plt.plot(other,ds.pedge)
#plt.gca().set_xscale('log')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#ds = xr.open_dataset('output.nc')
test = np.genfromtxt('../fortran/mat.out')
#dt = np.genfromtxt('del_T.out')
#res = np.genfromtxt('res.out')
#other = np.genfromtxt('test.out')
#testpy = np.genfromtxt('mat_py.out')
print(np.amax(test), np.amin(test))
# Out:
# 9.0218 -13.583

# %%
plt.imshow(np.linalg.inv(test.reshape((101,101))))
test2 = test.reshape((101,101))

plt.colorbar()
test2[:,5]
# Out:
# <img src="data:image/png;base64,..." width="640">
# array([ 5.3080e-04,  5.6647e-04,  6.2305e-04,  7.2243e-04,  9.6849e-04,
#        -1.5019e-04, -1.3675e-03, -1.0184e-03, -8.2085e-04, -6.9193e-04,
#        -5.9857e-04, -5.2501e-04, -4.6387e-04, -4.1134e-04, -3.6514e-04,
#        -3.2390e-04, -2.8684e-04, -2.5358e-04, -2.2391e-04, -1.9766e-04,
#        -1.7463e-04, -1.3604e-04, -8.5643e-05, -4.5754e-05, -1.9251e-05,
#        -2.7516e-06,  6.7970e-06,  1.1890e-05,  1.4332e-05,  1.5152e-05,
#         1.4946e-05,  1.4119e-05,  1.2957e-05,  1.1670e-05,  1.0408e-05,
#         9.2639e-06,  8.2834e-06,  7.4719e-06,  6.8131e-06,  6.2820e-06,
#         5.8520e-06,  5.4989e-06,  5.2012e-06,  4.9409e-06,  4.7036e-06,
#         4.4779e-06,  4.2544e-06,  4.0280e-06,  3.7971e-06,  3.5631e-06,
#         3.3285e-06,  3.0970e-06,  2.8714e-06,  2.6543e-06,  2.4468e-06,
#         2.2494e-06,  2.0619e-06,  1.8841e-06,  1.7158e-06,  1.5574e-06,
# ...

# %%
mat = test.reshape((101,101))
print(res)
print(other)
print(np.matmul(mat,-dt))#
my_dt = np.linalg.solve(mat,-res)
print(np.linalg.solve(mat, -res))
print(np.matmul(np.linalg.inv(mat),-res))
print(dt)
print(my_dt)

print(np.matmul(mat, -dt))
print(np.matmul(mat, -my_dt))
print(np.linalg.cond(mat))
print(np.linalg.cond(testpy))
# Out:
# [ 461.2     461.4     461.6     461.9     462.1     462.4     462.7
#   463.1     463.5     463.9     464.3     464.8     465.4     466.
#   466.6     467.3     468.      468.8     469.6     470.5     471.5
#   472.4     473.5     474.5     475.6     476.7     477.8     478.9
#   480.      481.      481.8     482.6     483.1     483.4     483.4
#   482.9     482.      480.4     478.2     475.      470.9     465.7
#   459.1     451.      441.2     429.5     415.7     399.8     381.5
#   360.7     337.4     311.6     283.4     253.      220.7     186.8
#   151.9     116.6      81.55     47.41     14.91    -15.32    -42.72
#   -66.89    -87.59   -104.7    -118.4    -128.9    -136.4    -141.2
#  -143.7    -144.2    -142.8    -139.7    -135.1    -129.2    -122.
#  -113.7    -104.5     -94.61    -84.13    -73.34    -62.46    -51.75
#   -41.46    -31.83    -23.06    -15.34     -8.783    -3.453     0.6592
#     3.627     5.58      6.686     7.132     7.106     6.773     6.266
# ...

# %%
plt.close()
plt.figure()
plt.imshow(test.reshape((101,101)))
plt.colorbar()
plt.figure()
plt.imshow(np.linalg.inv(testpy))
plt.colorbar()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
print(np.matmul(np.linalg.inv(test2),res))
print(dt)
# Out:
# [-316.48219698 1190.11571327 -795.14039762  288.94441845  -94.00701492
#   -63.64010024   94.14185583 -199.47204393  147.99368811 -182.43398699
#   184.09237193 -197.1504922   183.14253079 -208.22013068  211.9755091
#  -196.33894473  194.78216623 -151.5382426   145.98256073  -80.64056268
#    72.20068672   -4.66023865   29.08981032   22.5680209    29.05404396
#    21.43736913   40.81133305   17.18649807   48.41228151   18.28439807
#    54.6800027    21.22771006   52.82180227   33.33810512   45.35821128
#    44.73154802   41.59587737   51.58823849   41.21247243   55.26786892
#    43.33341272   55.87396117   46.16507748   56.96066577   48.2573785
#    57.68776682   50.08904262   58.25680845   50.72216221   59.18268844
#    50.90053657   59.44449804   50.76968321   58.85080131   50.36130254
#    57.64620107   49.33580547   55.823168     47.36357864   53.41048204
#    44.56549188   50.09843057   40.77725118   45.86314718   35.91466326
# ...

# %%
def analytic(p):
    g = 0.04
    t = (p/p[-1])*256
    sb = 5.67e-8
    fint = sb*70**4
    s = 1368/4
    
    t4 = fint*(t+1) + s*(1 + 1/g + (g - 1/g)*np.exp(-g*t))
    return (t4/2/sb)**(1/4)

# %%
plt.figure()
#tester = np.genfromtxt('Te.out')
ds.Te.plot(y='pedge')
plt.plot(analytic(ds.pfull), ds.pfull)
#plt.plot(tester, ds.pedge)
plt.gca().invert_yaxis()
plt.gca().set_yscale('log')

# %%
hello = np.genfromtxt('mat_py.out')
plt.figure()
plt.imshow(hello)
plt.colorbar()
# Out:
# <img src="data:image/png;base64,..." width="640">
