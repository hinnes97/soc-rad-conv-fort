# %%
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr
# %matplotlib notebook

# %%
plt.figure()
ds = xr.open_dataset('../fortran/output/output_matrix_h2h2.nc')
ds2 = xr.open_dataset('../fortran/output/output_timestep_0.01_2.nc')
ds3 = xr.open_dataset('../fortran/output/output_matrix_5band.nc')
#ds.Tf.plot(y='pfull')

ds.Tf.plot(y='pfull')
ds2.Tf.plot(y='pfull')
ds3.Te.plot(y='pedge')
#(ds3.Te[-1]*(ds3.pedge/ds3.pedge[-1])**(2./7.)).plot(y='pedge')
plt.gca().set_yscale('log')
plt.gca().invert_yaxis()
plt.figure()
ds3.q.plot(y='pedge')
plt.gca().set_yscale('log')
plt.gca().set_xscale('log')
plt.gca().invert_yaxis()
ds.close()
ds2.close()
ds3.close()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
ds3.q.plot(y='pedge')
plt.gca().set_yscale('log')
plt.gca().set_xscale('log')
plt.gca().invert_yaxis()
# Out:
# <img src="data:image/png;base64,..." width="640">
